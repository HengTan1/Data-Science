# %% [markdown]
# # Date Night Movie
#
# #### Grading:
#
#
# - Code: 90 pts
# - Markdown Documentation: 10 pts

# %% [markdown]
# In this assignment we are going to use pandas to figure out - What's the best **date-night movie**?
#
# This assignment is going to use
# - Joining
# - Groupby
# - Sorting

# %%
import os
import pandas as pd

# %% [markdown]
# ##### Read in the movie data: `pd.read_table`

# %%
def get_movie_data():
    
    unames = ['user_id','gender','age','occupation','zip']
    users = pd.read_table(os.path.join('../../Assignment2/data/users.dat'),
                          sep='::', header=None, names=unames)
    
    rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
    ratings = pd.read_table(os.path.join('../../Assignment2/data/ratings.dat'), 
                            sep='::', header=None, names=rnames)
    
    mnames = ['movie_id', 'title','genres']
    movies = pd.read_table(os.path.join('../../Assignment2/data/movies.dat'), 
                           sep='::', header=None, names=mnames)

    return users, ratings, movies

# %%
users, ratings, movies = get_movie_data()
# Out:
# <ipython-input-2-14cb2c752a54>:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users = pd.read_table(os.path.join('../../Assignment2/data/users.dat'),
# <ipython-input-2-14cb2c752a54>:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_table(os.path.join('../../Assignment2/data/ratings.dat'),
# <ipython-input-2-14cb2c752a54>:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_table(os.path.join('../../Assignment2/data/movies.dat'),

# %%
users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                            genres
# 0   Animation|Children's|Comedy,,
# 1  Adventure|Children's|Fantasy,,
# 2                Comedy|Romance,,
# 3                  Comedy|Drama,,
# 4                        Comedy,,

# %% [markdown]
# ##### Clean up the `movies`
#
# - Get the `year`
# - Shorten the `title`

# %%
tmp = movies.title.str.extract('(.*) \(([0-9]+)\)')
tmp.apply(lambda x:x[0] if len(x) > 0 else None)
tmp.apply(lambda x: x[0][:40] if len(x) > 0 else None)
# Out:
# 0    Toy Story
# 1         1995
# dtype: object

# %%
movies['year'] = tmp[1]
movies['short_title'] = tmp[0]

# %%
movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                            genres  year                  short_title
# 0   Animation|Children's|Comedy,,  1995                    Toy Story
# 1  Adventure|Children's|Fantasy,,  1995                      Jumanji
# 2                Comedy|Romance,,  1995             Grumpier Old Men
# 3                  Comedy|Drama,,  1995            Waiting to Exhale
# 4                        Comedy,,  1995  Father of the Bride Part II

# %% [markdown]
# ##### Join the tables with `pd.merge` (20 pts)

# %%
#merging all the data together
rating_and_users = pd.merge(ratings,users,on='user_id')
merged_data = pd.merge(rating_and_users,movies,on='movie_id')
merged_data.tail()
# Out:
#          user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 1000204     5949      2198       5  958846401      M   18          17  47901
# 1000205     5675      2703       3  976029116      M   35          14  30030
# 1000206     5780      2845       1  958153068      M   18          17  92886
# 1000207     5851      3607       5  957756608      F   18          20  55410
# 1000208     5938      2909       4  957273353      M   25           1  35401
#
#                                                title                  genres  \
# 1000204                           Modulations (1998)           Documentary,,
# 1000205                        Broken Vessels (1998)                 Drama,,
# 1000206                            White Boys (1999)                 Drama,,
# 1000207                     One Little Indian (1973)  Comedy|Drama|Western,,
# 1000208  Five Wives, Three Secretaries and Me (1998)            Documentary,
#
#          year                           short_title
# 1000204  1998                           Modulations
# 1000205  1998                        Broken Vessels
# 1000206  1999                            White Boys
# 1000207  1973                     One Little Indian
# 1000208  1998  Five Wives, Three Secretaries and Me

# %% [markdown]
# ##### What's the highest rated movie? (20 pts))

# %%
#temp value for comparing the movie rating
temp_rating = 0.0
#saving the highest rating movie id
highest_rating_movie = 0

#travsering through the all the movies
for x in range(0, merged_data.movie_id.max()+1):
    movie_list = merged_data.loc[merged_data['movie_id'] == x]
    
    #checking to see if the new movie in the list is higher if so replace it with this one
    if movie_list.rating.mean() > temp_rating:
        temp_rating = movie_list.rating.mean()
        highest_rating_movie = x
        
print(highest_rating_movie)
print(merged_data.loc[merged_data['movie_id'] == highest_rating_movie].head())
# Out:
# 787
#         user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 965717      149       787       5  977325719      M   25           1  29205
# 965718     2825       787       5  972610193      F   25          20  94014
# 965719     2872       787       5  972423586      M   25          20  94014
#
#                                      title        genres  year  \
# 965717  Gate of Heavenly Peace, The (1995)  Documentary,  1995
# 965718  Gate of Heavenly Peace, The (1995)  Documentary,  1995
# 965719  Gate of Heavenly Peace, The (1995)  Documentary,  1995
#
#                         short_title
# 965717  Gate of Heavenly Peace, The
# 965718  Gate of Heavenly Peace, The
# 965719  Gate of Heavenly Peace, The

# %% [markdown]
# ###### What is a good rated movie for date night? (60 pts)
#
# - Hint - highly rated movie by
#     - both partners (might be the same gender or not),
#     - based on genre preferences,
#     - age group can also be combined

# %%
#looking at genre to pick out what there are
merged_data.genres.unique()
# Out:
# array(['Drama,,', "Animation|Children's|Musical,,", 'Musical|Romance,,',
#        "Animation|Children's|Comedy,", 'Action|Adventure|Comedy|Romance,',
#        'Action|Adventure|Drama,,', 'Comedy|Drama,',
#        "Adventure|Children's|Drama|Musical,", 'Musical,,', 'Comedy,,',
#        'Musical,', "Animation|Children's,,", 'Comedy|Fantasy,,',
#        'Animation,,', 'Comedy|Sci-Fi,,', 'Drama|War,,', 'Romance,,',
#        "Animation|Children's|Musical|Romance,,",
#        "Children's|Drama|Fantasy|Sci-Fi,,", 'Drama|Romance,,',
#        'Animation|Comedy|Thriller,', 'Drama,',
#        "Adventure|Animation|Children's|Comedy|Musical,,",
#        "Animation|Children's|Comedy|Musical,,",
#        "Animation|Children's|Musical,", 'Thriller,',
#        "Animation|Children's|Comedy,,", 'Action|Crime|Romance,,',
#        'Action|Adventure|Fantasy|Sci-Fi,,', "Children's|Comedy|Musical,,",
#        'Action|Drama|War,,', "Children's|Drama,",
#        'Crime|Drama|Thriller,,', 'Action|Crime|Drama,',
#        'Action|Adventure|Mystery,,', 'Crime|Drama,',
#        'Action|Adventure|Sci-Fi|Thriller,,',
#        'Action|Adventure|Romance|Sci-Fi|War,,', 'Action|Thriller,,',
#        'Action|Thriller,', 'Crime|Drama,,', 'Action|Drama,,',
#        'Comedy|Drama|Western,,', 'Action|Adventure|Crime,,',
#        'Action|Crime|Mystery|Thriller,,', 'Comedy|Drama|Romance,',
#        'Comedy|Drama|War,,', 'Drama|Sci-Fi,', 'Action|Drama|Thriller,,',
#        'Action|Comedy|Western,,', 'Adventure|Comedy|Drama,,',
#        'Drama|Thriller,', 'Action|Adventure|Sci-Fi|Thriller,',
#        'Comedy|Romance,,', 'Action|Drama|Romance|Thriller,',
#        'Action|Crime|Thriller,,', 'Drama|Sci-Fi,,',
#        'Action|Sci-Fi|Thriller,,', 'Action|Horror|Sci-Fi,,',
#        'Action|Drama|War,', 'Comedy|Drama,,', 'Action|Sci-Fi,,',
#        'Action|Romance|War,', 'Adventure|Drama|Romance|Sci-Fi,,',
#        'Action|Adventure|Sci-Fi,,', 'Drama|Romance|War,,',
#        'Action|Drama|Romance,', 'Crime|Drama|Film-Noir|Thriller,,',
#        'Adventure|Drama|Western,,', 'Action|Adventure|Drama|Sci-Fi|War,,',
#        'Action|Adventure|Thriller,,',
#        'Action|Adventure|Romance|Thriller,,', 'Action|Adventure,,',
#        'Comedy|Horror,,', 'Action|Sci-Fi|Thriller,',
#        'Action|Crime|Drama|Thriller,',
#        'Action|Mystery|Romance|Thriller,,', 'Action|Romance|Thriller,,',
#        'Action|Comedy|Drama,,', 'Action|Adventure|Comedy|Romance,,',
#        'Action,', 'Action|Sci-Fi,', 'Action,,', 'Action|Sci-Fi|War,,',
#        'Action|Comedy|Crime|Drama,,', 'Action|Adventure|Romance,',
#        'Comedy|Drama|Romance,,', 'Comedy|Romance|War,,',
#        'Comedy|Thriller,,', 'Drama|Romance,', 'Comedy,',
#        'Action|Adventure|Comedy,', 'Action|Comedy,,',
#        'Adventure|Thriller,', 'Action|Adventure|Fantasy,,',
#        'Action|Adventure|Horror,,', 'Action|Adventure|Comedy|Sci-Fi,,',
#        'Action|Adventure,', 'Action|Adventure|Comedy|Horror,,',
#        'Western,,', 'Action|Adventure|Thriller,', 'Adventure|Comedy,,',
#        'Adventure|Drama,,', 'Action|Adventure|Horror|Thriller,',
#        'Comedy|Western,,', 'Adventure|Thriller,,',
#        "Animation|Children's|Comedy|Musical|Romance,", 'Action|Western,',
#        'Action|Horror|Sci-Fi|Thriller,,', 'Action|Horror,,',
#        'Action|Western', 'Adventure|Animation|Film-Noir,,', 'Comedy',
#        'Drama|Romance|Thriller,', 'Crime|Drama|Romance|Thriller,,',
#        'Drama|War,', 'Crime|Thriller,,', 'Animation|Comedy,',
#        'Documentary,', 'Crime|Film-Noir|Mystery|Thriller,,',
#        'Drama|Horror,,', 'Mystery|Sci-Fi|Thriller,', 'Thriller,,',
#        'Drama|Thriller,,', 'Drama|Mystery,,', 'Crime|Thriller,',
#        'Documentary,,', 'Horror|Romance,,', 'Horror|Sci-Fi,', 'Horror,,',
#        'Action|Adventure|Comedy,,', 'Sci-Fi|Thriller,,', 'Crime,,',
#        'Action|Crime,,', 'Horror|Sci-Fi,,', 'Crime|Horror,,',
#        'Drama|Mystery|Thriller,', 'Comedy|Crime,,',
#        'Drama|Sci-Fi|Thriller,,', "Children's|Comedy,,",
#        'Horror|Mystery|Thriller,,', "Children's|Comedy|Musical,",
#        'Comedy|Romance,', 'Film-Noir|Mystery,',
#        'Comedy|Crime|Mystery|Thriller,', 'Drama|Musical,',
#        'Adventure|Sci-Fi,', 'Action|Romance|Thriller,',
#        "Children's|Comedy|Drama,,", 'Action|Romance,,',
#        "Adventure|Animation|Children's|Musical,,", 'Western,',
#        "Children's|Comedy,", 'Comedy|Musical,,',
#        "Children's|Fantasy|Musical,,", "Children's|Comedy|Western,",
#        'Drama|Romance|War|Western,,', 'Drama|Musical',
#        "Adventure|Children's|Comedy,,", 'Comedy|Fantasy|Romance,,',
#        'Comedy|Musical|Romance,,', 'Drama|Romance|Thriller,,', 'Horror,',
#        'Action|Crime|Drama,,', "Adventure|Children's|Drama,,",
#        'Action|Drama|Thriller|War,', 'Drama|Thriller|War,,',
#        'Adventure|Animation|Sci-Fi|Thriller,,', 'Animation|Sci-Fi,,',
#        'Action|Drama|Romance,,', 'Comedy|Crime|Drama|Mystery,,',
#        'Crime|Drama|Mystery,,', 'Drama|Mystery,', 'Comedy|Drama',
#        'Action|Comedy|Sci-Fi|Thriller,,', 'Comedy|Crime|Fantasy,',
#        'Comedy|Crime,', 'Horror|Sci-Fi|Thriller,,', 'Romance,',
#        'Comedy|Fantasy,', "Adventure|Children's|Comedy|Fantasy|Sci-Fi,",
#        'Film-Noir|Mystery|Thriller,,', 'Adventure,', 'Comedy|War,,',
#        'Comedy|Romance|Thriller,,', "Action|Children's|Fantasy,,",
#        "Adventure|Children's|Fantasy,,",
#        'Action|Adventure|Comedy|Crime,,', 'Adventure|Musical,,',
#        "Animation|Children's|Drama|Fantasy,,",
#        'Comedy|Mystery|Thriller,,', 'Action|Adventure|Crime|Drama,,',
#        "Children's|Fantasy|Sci-Fi,", "Adventure|Children's,",
#        "Animation|Children's|Comedy|Musical,", 'War,,',
#        'Comedy|Horror|Musical|Sci-Fi,', "Children's|Comedy|Fantasy,",
#        "Animation|Children's|Comedy|Musical|Romance,,", 'Sci-Fi|War,,',
#        "Animation|Children's|Fantasy|Musical,,", 'Action|Sci-Fi|War,',
#        'Comedy|Musical,', "Adventure|Children's|Fantasy,",
#        "Animation|Children's,", "Children's|Sci-Fi,,",
#        "Adventure|Children's|Fantasy|Sci-Fi,,", 'Mystery|Thriller,,',
#        'Action|Adventure|Sci-Fi,', 'Comedy|Horror|Musical,,',
#        "Children's|Drama,,", 'Action|Horror|Thriller,',
#        "Adventure|Children's,,", "Adventure|Children's|Fantasy|Sci-Fi,",
#        'Adventure|Fantasy,,', 'Drama|Mystery|Sci-Fi|Thriller,,',
#        'Crime|Drama|Sci-Fi,,', "Adventure|Children's|Musical,,",
#        'Action|Adventure|Fantasy,', 'Action|Sci-Fi|Thriller|War,,',
#        'Adventure|War,,', 'Action|Adventure|Romance|War,',
#        'Action|Drama|Fantasy|Romance,,', 'Adventure|Comedy|Sci-Fi,,',
#        'Comedy|Sci-Fi|Western,,',
#        'Action|Adventure|Comedy|Horror|Sci-Fi,,',
#        "Adventure|Children's|Comedy|Fantasy,,", 'Film-Noir|Sci-Fi,,',
#        'Drama|Fantasy,', "Children's|Drama|Fantasy,,",
#        "Children's|Fantasy,", 'Fantasy|Sci-Fi,,',
#        'Action|Comedy|Musical,', 'Adventure|Fantasy|Sci-Fi,,',
#        'Action|Adventure|Sci-Fi|War,,',
#        "Action|Adventure|Children's|Comedy,,",
#        "Adventure|Children's|Drama|Romance,",
#        "Adventure|Children's|Sci-Fi,,", "Children's,",
#        'Comedy|Drama|War,', 'Comedy|Drama|Musical,,',
#        'Comedy|Fantasy|Romance|Sci-Fi,', 'Comedy|Crime|Drama,,',
#        'Sci-Fi,,', 'Adventure|War,', 'Adventure,,',
#        'Adventure|Fantasy|Romance,,', 'Adventure|Romance,,',
#        'Adventure|Western,,', 'Adventure|Comedy|Sci-Fi,',
#        'Action|Drama|Mystery,,', 'Adventure|Animation|Sci-Fi,,',
#        'Action|Adventure|Drama,', 'Adventure|Romance,',
#        'Adventure|Romance|Sci-Fi,,', 'Horror|Thriller,',
#        'Action|Adventure|Mystery|Sci-Fi,,', 'Adventure|Drama|Thriller,,',
#        'Comedy|Horror|Thriller,,', 'Crime|Drama|Thriller,',
#        'Mystery|Thriller,', 'Drama|Musical,,',
#        "Children's|Comedy|Fantasy,,",
#        'Action|Comedy|Crime|Horror|Thriller,,',
#        'Crime|Horror|Mystery|Thriller,', 'Crime|Horror|Thriller,,',
#        'Crime|Drama|Mystery|Thriller,,', 'Animation|Musical,',
#        'Action|Sci-Fi|Western,,', 'Action|Crime,', 'Horror|Thriller,,',
#        'Crime|Drama|Film-Noir,', 'Sci-Fi|Thriller,',
#        'Adventure|Sci-Fi|Thriller,,', 'Drama|Fantasy|Romance|Thriller,,',
#        'Sci-Fi,', 'Mystery|Sci-Fi,,', 'Adventure|Fantasy|Sci-Fi,',
#        'Action|Crime|Sci-Fi,,', 'Comedy|Mystery,,', 'Adventure|Drama,',
#        'Action|Romance|Sci-Fi,,', 'Crime|Drama|Film-Noir,,',
#        'Action|Horror|Sci-Fi,', 'Crime|Drama|Romance|Thriller,',
#        'Crime|Film-Noir|Mystery,,', 'Comedy|Drama|Sci-Fi,,',
#        'Sci-Fi|Thriller|War,,', 'Action|Horror|Sci-Fi|Thriller,',
#        'Film-Noir|Thriller,',
#        'Action|Adventure|Animation|Horror|Sci-Fi,,',
#        'Action|Sci-Fi|Thriller|Western,,', 'Comedy|Horror|Sci-Fi,,',
#        'Crime|Film-Noir|Thriller,,', 'Comedy|Crime|Thriller,',
#        'Film-Noir|Sci-Fi|Thriller,,', 'Adventure|Sci-Fi,,',
#        "Adventure|Animation|Children's|Sci-Fi,", 'Drama',
#        'Action|Adventure|Drama|Romance,,', 'Film-Noir|Thriller,,',
#        "Children's|Musical,", 'Action|Comedy|Musical|Sci-Fi,,',
#        'Action|Drama|Sci-Fi|Thriller,,', 'Action|Comedy|Fantasy,,',
#        'Action|War,,', 'Action|Comedy|Sci-Fi|War,,',
#        'Action|Adventure|Drama', 'Comedy|Crime|Horror,,',
#        'Action|Comedy|War,,', "Action|Adventure|Children's|Sci-Fi,,",
#        "Action|Children's,,", 'Drama|Romance|War,', 'Horror|Romance,',
#        'Comedy|Documentary,,', 'Action|Comedy|Musical,,',
#        'Action|Adventure|Animation,', 'Action|Mystery|Thriller,,',
#        'Comedy|Mystery,', 'Animation|Comedy,,', 'Comedy|Horror,',
#        "Action|Animation|Children's|Sci-Fi|Thriller|War,",
#        'Crime|Drama|Romance,,', 'Crime|Film-Noir,,', 'Crime|Film-Noir,',
#        'Mystery|Romance|Thriller,,', 'Comedy|Mystery|Romance|Thriller,,',
#        'Action|Adventure|Sci-Fi|Thriller|War,,', 'Crime,',
#        'Adventure|Crime|Sci-Fi|Thriller,,', 'Drama|Fantasy',
#        'Action|Adventure|Western,', 'Comedy|Romance',
#        "Animation|Children's|Fantasy|War,,",
#        'Action|Adventure|Comedy|War,,', "Children's|Comedy|Sci-Fi,",
#        'Drama|Horror,', "Adventure|Animation|Children's|Comedy|Fantasy,,",
#        'Drama|Musical|War,,', 'Action|Drama|Romance|Thriller,,',
#        'Action|Drama,', 'Drama|Mystery|Romance,,',
#        'Adventure|Drama|Romance,', 'Film-Noir,,',
#        'Film-Noir|Romance|Thriller,,', 'Drama|Film-Noir,,',
#        'Romance|Thriller,,', 'Action|Adventure|War,,', 'Action|War,',
#        'Comedy|Mystery|Romance|Thriller,', 'Comedy|Musical|Romance,',
#        'Film-Noir,', 'Mystery,,', 'Action|Adventure|Drama|Thriller,,',
#        'Musical|Romance|War,,', 'Mystery,', 'Drama|Western,,',
#        'Action|Drama|Mystery|Romance|Thriller,,',
#        'Adventure|Comedy|Musical,,', 'Animation|Musical,,',
#        'Comedy|Documentary,', 'Documentary|Musical,,',
#        'Action|Thriller|War,', 'Adventure|Comedy|Romance,,',
#        "Adventure|Children's|Comedy|Fantasy|Romance,", 'Romance|War,',
#        'Romance|Thriller,', 'Comedy|Romance|Sci-Fi,,',
#        'Action|Mystery|Sci-Fi|Thriller,,', "Children's|Horror,,",
#        'Adventure|Musical|Romance,',
#        "Adventure|Children's|Comedy|Musical,,", 'Comedy|Crime|Thriller,,',
#        'Musical|Romance,', "Children's|Comedy|Mystery,,", 'Romance|War,,',
#        'Action|Comedy|Romance|Thriller,,', 'Action|Drama|Western,,',
#        "Animation|Children's|Comedy|Romance,",
#        'Action|Adventure|Romance,,', 'Comedy|Mystery|Romance,,',
#        'Comedy|Sci-Fi,', 'Action|Crime|Mystery,,',
#        'Comedy|Drama|Thriller,', "Adventure|Children's|Comedy|Fantasy,",
#        "Children's,,", 'Comedy|Horror', 'Musical|War,,', 'War,',
#        'Documentary|Drama,,', 'Drama|Sci-Fi|Thriller,',
#        'Action|Adventure|Crime|Thriller,,',
#        "Action|Adventure|Children's,,", "Action|Children's,",
#        "Adventure|Children's|Romance,",
#        "Adventure|Animation|Children's,,",
#        "Action|Adventure|Animation|Children's|Fantasy,", 'Action|Comedy,',
#        "Children's|Musical,,", "Adventure|Animation|Children's|Fantasy,,",
#        'Drama|Film-Noir|Thriller,', 'Crime|Drama|Romance,',
#        'Crime|Mystery,', 'Documentary|War,,', 'Animation|Sci-Fi,',
#        'Adventure|Drama|Romance,,', 'Drama|Fantasy,,',
#        'Action|Comedy|Crime,,', 'Drama|Romance|Sci-Fi,,', 'Documentary',
#        'Horror|Mystery,', 'Drama|Horror|Thriller,,',
#        'Comedy|Horror|Thriller,', 'Action|Crime|Romance,',
#        "Children's|Comedy", 'Action|Horror,',
#        "Action|Adventure|Children's|Fantasy,,", 'Animation|Mystery,,',
#        'Drama|Romance|Western,,', 'Romance|Western,', 'Action|Comedy',
#        'Crime|Horror,', 'Comedy|Film-Noir|Thriller,,',
#        'Animation|Comedy|Thriller,,', 'Fantasy,', 'Crime|Drama|Mystery,',
#        'Drama|Western,', 'Action|Drama', 'Film-Noir|Horror,,',
#        'Comedy|Western,', 'Romance'], dtype=object)

# %%
#gets all the genre that is being searched for 
genre = merged_data.loc[merged_data['genres'].str.contains('Drama' and 'Sci-Fi')]

#divides the dataframe into Male and Female
male = genre.loc[genre['gender'] == 'M']
female = genre.loc[genre['gender'] == 'F']

# %%
genre.head()
# Out:
#        user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 23270        1      1270       5  978300055      F    1          10  48067
# 23271        3      1270       3  978298231      M   25          15  55117
# 23272        7      1270       4  978234581      M   35           1  06810
# 23273       10      1270       4  978225735      F   35           1  95370
# 23274       17      1270       5  978158536      M   50           1  95350
#
#                            title           genres  year         short_title
# 23270  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23271  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23272  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23273  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23274  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future

# %%
male.head()
# Out:
#        user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 23271        3      1270       3  978298231      M   25          15  55117
# 23272        7      1270       4  978234581      M   35           1  06810
# 23274       17      1270       5  978158536      M   50           1  95350
# 23275       19      1270       5  978557301      M    1          10  48073
# 23276       22      1270       4  978152904      M   18          15  53706
#
#                            title           genres  year         short_title
# 23271  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23272  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23274  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23275  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23276  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future

# %%
female.head()
# Out:
#        user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 23270        1      1270       5  978300055      F    1          10  48067
# 23273       10      1270       4  978225735      F   35           1  95370
# 23277       24      1270       4  978131939      F   25           7  10023
# 23282       34      1270       5  978102954      F   18           0  02135
# 23286       45      1270       5  977990190      F   45          16  94110
#
#                            title           genres  year         short_title
# 23270  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23273  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23277  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23282  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future
# 23286  Back to the Future (1985)  Comedy|Sci-Fi,,  1985  Back to the Future

# %%
#temp variable
temp = 0.0
#gets movie_id in the conditional
highest_rating_both = 0

#go through all the movies
for x in range(0, genre.movie_id.max()+1):
    males = male.loc[male['movie_id'] == x]
    females = female.loc[female['movie_id'] == x]
    
    #if there is at least 10 rated movies
    if len(genre[genre['movie_id'] == x].rating) >= 10:
        #find the highest rating separated from male and female then combine them afterwards
        if males.rating.mean() + females.rating.mean() > temp:
            temp = males.rating.mean() + females.rating.mean()
            highest_rating_both = x
            
print(highest_rating_both)
print(merged_data.loc[merged_data['movie_id'] == highest_rating_both].head())
# Out:
# 750
#         user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 454160       10       750       4  979775386      F   35           1  95370
# 454161       17       750       5  978160490      M   50           1  95350
# 454162       23       750       4  978463892      M   35           0  90049
# 454163       40       750       4  978041037      M   45           0  10543
# 454164       42       750       4  978039170      M   25           8  24502
#
#                                                     title        genres  year  \
# 454160  Dr. Strangelove or: How I Learned to Stop Worr...  Sci-Fi|War,,  1963
# 454161  Dr. Strangelove or: How I Learned to Stop Worr...  Sci-Fi|War,,  1963
# 454162  Dr. Strangelove or: How I Learned to Stop Worr...  Sci-Fi|War,,  1963
# 454163  Dr. Strangelove or: How I Learned to Stop Worr...  Sci-Fi|War,,  1963
# 454164  Dr. Strangelove or: How I Learned to Stop Worr...  Sci-Fi|War,,  1963
#
#                                               short_title
# 454160  Dr. Strangelove or: How I Learned to Stop Worr...
# 454161  Dr. Strangelove or: How I Learned to Stop Worr...
# 454162  Dr. Strangelove or: How I Learned to Stop Worr...
# 454163  Dr. Strangelove or: How I Learned to Stop Worr...
# 454164  Dr. Strangelove or: How I Learned to Stop Worr...

# %% [markdown]
# This is a 3 part program. The first part was to read all the files toegether and display them all together. The second part was to give the highest rating movie in the text file. The third part of the program was to display the best recommended movie based on a male and a female preferences. I decided to display the male and female preferences by picking the genres Drama and Sci-fi. After getting all the movies in those two genres. The program will then display the male and females highest rated movie for that conditional of Drama and Sci-fi. After getting the highest of the male and female rated movies then it will combine the data and display the best recommended movie in that genre.
